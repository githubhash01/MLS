# %%
import matplotlib.pyplot as plt
import pandas as pd

# # Load the results from the CSV file
# df = pd.read_csv("knn_recall_vs_clusters.csv")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /afs/inf.ed.ac.uk/user/s22/s2261580/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import pandas as pd
#       4 # # Load the results from the CSV file
#       5 # df = pd.read_csv("knn_recall_vs_clusters.csv")
#
# File /usr/lib/python3/dist-packages/pandas/__init__.py:28
#      25 del hard_dependencies, dependency, missing_dependencies
#      27 # numpy compat
# ...
